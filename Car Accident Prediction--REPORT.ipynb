# %% [markdown]
# # Car Accident Prediction

# %% [markdown]
# **Business Understanding :**  As per WHO figures approximately 1.35 million people die in rod accident every year. This is obviously a matter of concern for Civic Authorities all around the world wherein authorities try to understand what are the factors that cause these accidents and how these could be reduced. Given this background we will try to analyze the car accident data form Seattle City public authorities and try to understand what casuse these accidents and how it can be prevented.

# %% [markdown]
# **Data Understanding:**  Data has bee taken from https://data-seattlecitygis.opendata.arcgis.com/. In trying to predict an accident given some historical data, the features that prevailed just before the accident becomes important. We will emphasize our predication based on those features like Road condition, Light Condition etc. that prevailed just before the collisions. Some data not relevant to the analysis will be dropped.

# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Collisions.csv")

# %%
df.head(20)
# Out:
#              X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO     STATUS  \
# 0  -122.356511  47.517361         1  327920     329420  3856094    Matched
# 1  -122.361405  47.702064         2   46200      46200  1791736    Matched
# 2  -122.317414  47.664028         3    1212       1212  3507861    Matched
# 3  -122.318234  47.619927         4  327909     329409  EA03026    Matched
# 4  -122.351724  47.560306         5  104900     104900  2671936    Matched
# 5  -122.333067  47.544302         6  322205     323705  3694789    Matched
# 6  -122.338543  47.616874         7  322275     323775  E949282    Matched
# 7          NaN        NaN         8    5721       5721  1786583  Unmatched
# 8  -122.360959  47.571594         9   33400      33400  1076890    Matched
# 9  -122.336856  47.655652        10   20400      20400  1220377    Matched
# 10 -122.316123  47.607424        11    1018       1018  3645722  Unmatched
# ...

# %%
df.dtypes
# Out:
# X                  float64
# Y                  float64
# OBJECTID             int64
# INCKEY               int64
# COLDETKEY            int64
# REPORTNO            object
# STATUS              object
# ADDRTYPE            object
# INTKEY             float64
# LOCATION            object
# EXCEPTRSNCODE       object
# EXCEPTRSNDESC       object
# SEVERITYCODE        object
# SEVERITYDESC        object
# COLLISIONTYPE       object
# PERSONCOUNT          int64
# PEDCOUNT             int64
# PEDCYLCOUNT          int64
# VEHCOUNT             int64
# INJURIES             int64
# SERIOUSINJURIES      int64
# FATALITIES           int64
# INCDATE             object
# INCDTTM             object
# JUNCTIONTYPE        object
# SDOT_COLCODE       float64
# SDOT_COLDESC        object
# INATTENTIONIND      object
# UNDERINFL           object
# WEATHER             object
# ROADCOND            object
# LIGHTCOND           object
# PEDROWNOTGRNT       object
# SDOTCOLNUM         float64
# ...

# %% [markdown]
# Features like OBJECTID,SHAPE,INCKEY,COLDETKEY,EXCEPTRSNCODE,EXCEPTRSNDESC,SDOT_COLCODE,SDOT_COLDESC can be dropped at the first glance itself as they are some codes given by the authorities for book keeping after the accident have taken place .
#
# Time to time we will study all the other features , clean them and further drop few more features not related to the analysis.

# %% [markdown]
# **Data Preparation:** After the data is loaded its time to prepare the data by cleaning it and finding various insights using exploratory techniques. The step by step data cleaning procedures is clearly explained in the full notebook avaialble. Here we shall discuss the various initital inference that we found during our analysis. <br>
# 1) **Most of the accidents resulted in property damage**<br>
# 2) **Most of the accidents happened during daylight and in clear skies compared to night. The darkness of night might make the drivers more cautious while driving , this might result in lower accident in night. In day and under clear skies drivers drive with more confidence which may soemthimes end up in rash driving hence causing these accidents.**<br>
# 3) **Most of the accidents occurede in the month of October**<br>
# 4) **Most accidents happened in the year 2006. Since then there has been considerable improvement in road travel resulting in lesser accidents.**

# %% [markdown]
# **Modeling:** After the data is cleaned we are ready for trying out various models that fit our data. We fittd the data in models like KNN, SVM, DECISSION TREE and LOGISTIC REGRESSION. The result of all these models are documented in the final notebook shared with this project.

# %% [markdown]
# **Evaluation:** All the models where the data was fitted were evaluated against jaccard index, f1 score and logloss. Turned out that logistic regression gave us a much better models among all the models tested.
